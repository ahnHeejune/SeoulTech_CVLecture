# %% [markdown]
# ## 신경망 구조
#
# 1. Fully Connected NN
# 2. Convolutional NN
# 3. Recurrent NN
# 4. Transformer NN

# %% [markdown]
# ## 1. FCNN

# %% [markdown]
# ## 2. CNN
#
# - Convolution은 사실상 Filter 또는 Correlation을 의미
#      - 역할을 kernel 과 유사한 패턴을 찾아 내는 역할 임. 즉, 일정한 패턴을 갖는 입력이 어느정도 있는지를 출력
#      - 고전적인 필터들은 이 패턴 값이 고정되어 있고,  NN은 이 패턴을 하습에의하여 찹아 냄

# %% [markdown]
# ## 3. RNN
#
# - Recurrent는  다시 돌아온다는 뜻.  출력 결과또는 현재 상태값이 다시 입력으로 반영되어 다음 결과에 영향을 준다는 것임.
# - 반면 이전의 FCNN, CNN은 현재 입력 값만이  출력에 영향을 줌.
# - 보통 시간적으로 입력되는 데이터에서 사용되나  다은 경우로 확장도 가능함.
# - 상당히 많은 경우 이전의 입력값이 없어져도 다음 상태와 추정에 영향을 주는 경우가 많음, 대표적으로 문장의 의미 등  (이를 컨캑스트라고함)
#     -   문맥의 예
#
# -

# %% [markdown]
# ## 4. Transfomer NN
#
# - RNN에서 과거의 정보를 계속해서 상태로 업데이트 함으로서 상태 값에 과부화가 걸림.
#
#     -  비유: 우리가 잛은 영어 문장은 한국어러 해석이 가능하지만, 영어가 길어지면 앞에서 뭔 말을 했는지 기억이 되지 않는 현상이 발생
#     -  이러한 것을 해결하기 위하여 ....
#
# - CNN에서는 입력간의 상관관계가 하나로 고정됨 (학습이후에는)
#     -  입력에 따라서 상관도가 달라짐  (적응적임) : 이를 attension 이라고 부름
#     -
